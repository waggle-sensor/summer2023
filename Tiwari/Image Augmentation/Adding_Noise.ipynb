# %%
import cv2
import numpy as np
from PIL import Image
from IPython import display
import PIL
import random
import skimage
import skimage.util
from skimage.util import random_noise
import matplotlib.pyplot as plt
import os

# %%
img_dir = "/home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b"
for filename in os.listdir(img_dir):
    try :
        with Image.open(img_dir + "/" + filename) as im:
            print('ok')
    except :
        print(img_dir + "/" + filename)
        os.remove(img_dir + "/" + filename)
# Out:
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok

# %%
car_pic = ""

pts = []

# Mouse-click event function credits: https://stackoverflow.com/questions/32770654/get-pixel-location-using-mouse-click-events/60445099#60445099

# click_event: stores a list of coordinate points clicked on by user 
# Args: 
#       event: type of click/event performed
#       x/y: coordinate positions
#       flags, param: any relevant flags or extra parameters provided by opencv library

def click_event(event, x, y, flags, param):



    if event == cv2.EVENT_LBUTTONDOWN:
        print(x,",",y)

        # np.append(pts, [x,y])
        global pts
        
        # pts = np.append(pts,[[x,y]])
        # pts = np.float32(pts)
        
        pts.append([x,y])
        
        font = cv2.FONT_HERSHEY_SIMPLEX
        strXY = str(x)+", "+str(y)
        img = cv2.imread(car_pic)
        cv2.putText(img, strXY, (x,y), font, 0.5, (255,255,0), 2)

        cv2.circle(img, (x,y), radius = 0, color = (0, 0, 255), thickness = -1)
        
        cv2.imshow(car_pic, img)
        # print("PTS", pts)
        # return pts
    if event == cv2.EVENT_RBUTTONDOWN:
        return
        # return pts



# random_sticker: chooses random picture from ridesharing stickers collection
# args: none
# returns a random image
import glob 

def random_sticker():
    file_path = ["/home/tiwari/Waggle-Private Folder/Ridesharing Stickers/*.png"]
    images = glob.glob(random.choice(file_path))
    random_img = random.choice(images)
    return random_img



# setSticker: overlays Uber sticker on every car present in image
# Args: 
#       img_name: image path

def setSticker(img_name):
    
    global car_pic
    car_pic = img_name
    img = cv2.imread(car_pic)

    cv2.imshow(car_pic, img)
    
    rndm_sticker = random_sticker()
    sticker = cv2.imread(rndm_sticker)
    print(rndm_sticker)
    print(random.choice(["front", "back"]))
    
    #Change darkness of sticker
    # define the alpha and beta
    alpha = 0.7 # Contrast control
    beta = 1 # Brightness control

    # call convertScaleAbs function
    sticker = cv2.convertScaleAbs(sticker, alpha=alpha, beta=beta)


    cv2.setMouseCallback(img_name, click_event)
    global pts
    # print(pts)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    pts = np.float32(pts)

    #edge case - no cars in pic
    if (pts.size == 0):
        cv2.destroyAllWindows()
        return []
        

    sticker = cv2.cvtColor(sticker,cv2.COLOR_BGR2RGB)
    background = cv2.imread(img_name)
    background = cv2.cvtColor(background,cv2.COLOR_BGR2RGB)
    height = sticker.shape[0]
    width = sticker.shape[1]



    rows,cols,ch = background.shape

    pts1 = np.float32([[0,0],[width,0],[0,height],[width,height]]) # cola coords 
    pts2 = pts # stadium tile coords
    pts2 = np.float32(pts2)
    # print("pts", pts)

    M = cv2.getPerspectiveTransform(np.float32(pts1),np.float32(pts2))    
    dst = cv2.warpPerspective(sticker,M,(cols,rows))

    overlay = cv2.add(background, dst)
    # Image.fromarray(overlay).save("final22.png")
    return overlay

# %%
# Function for adding Noise: 

def add_noise(image):
    types = ['gaussian', 'salt', 'pepper', 'speckle', 's&p', 'gaussian']
    my_img = cv2.imread(image)
    
    # Add random type of noise to the image.
    my_noise = random.choice(types)
    noise_img = random_noise(my_img, mode= my_noise)
    
    # The above function returns a floating-point image
    # on the range [0, 1], thus we changed it to 'uint8'
    # and from [0,255]
    noise_img = np.array(255*noise_img, dtype = 'uint8')
    cv2.imwrite(image, noise_img)

# %%
# Divide into quadrants and overlay sticker on all node pictures

import os
from os import listdir
import glob

# Divide all images from Waggle Node W026 (from May 31 - June1) into quadrants and overlay sticker on each picture


count = 0
# folder_dir = '/Users/anaghatiwari/Documents/CarPics/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d05a1c7'

# '/home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3af41e' 
# '/home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d05a1c2'
# /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b
for images in glob.glob('/home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/*.jpg'):
    name = os.path.dirname(images)
    car = cv2.imread(images)

    print("IMAGES: ", images)

    (h, w) = car.shape[:2]
    (center_x, center_y) = (w//2, h//2)

    top_left = car[0:center_y, 0:center_x]
    top_right = car[0:center_y, center_x:w]
    bot_left = car[center_y:h, 0:center_x]
    bot_right = car[center_y:h, center_x:w]
    # global pts
        
    # Store quadrant images as new file, call SetSticker function to overlay sticker in each quadrant

    for i in range(4):

        if i == 0:
            global pts
            pts = []
            cv2.imwrite(str(count)+"q1.jpeg", top_left)
            overlay = setSticker(str(count) + "q1.jpeg")
            if (len(overlay) > 0):
                Image.fromarray(overlay).save(str(count) + "q1.jpeg")
                add_noise(str(count) + "q1.jpeg")

        elif i ==1:
            pts = []
            cv2.imwrite(str(count)+'q2.jpeg', top_right)
            overlay = setSticker(str(count) + "q2.jpeg")
            if (len(overlay) >0):
                Image.fromarray(overlay).save(str(count) + "q2.jpeg")
                add_noise(str(count) + "q2.jpeg")

        elif i ==2:
            pts = []
            cv2.imwrite(str(count)+'q3.jpeg', bot_left)

            overlay = setSticker(str(count) + "q3.jpeg")
            if (len(overlay) > 0):
                Image.fromarray(overlay).save(str(count) + "q3.jpeg")
                add_noise(str(count) + "q3.jpeg")

        else:
            pts = []
            cv2.imwrite(str(count)+'q4.jpeg', bot_right)
            overlay = setSticker(str(count) + "q4.jpeg")
            if (len(overlay) > 0):
                Image.fromarray(overlay).save(str(count) + "q4.jpeg")
                add_noise(str(count) + "q4.jpeg")
    
    # increments count (used to create new file name for each quadrant) 
    count += 1
    
    pts = []

    # print("COUNT: ", count)
    # cv2.waitKey(0)
    # cv2.destroyAllWindows()
    # print("next iteration now")

# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683633626915908157-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 5.png
# back
# 455 , 526
# 465 , 521
# 460 , 533
# 470 , 528
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle2.png
# back
# 1248 , 739
# 1261 , 744
# 1247 , 750
# 1259 , 754
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 4.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684400409548452680-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber.png
# back
# 92 , 555
# 101 , 550
# 96 , 562
# 105 , 556
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U2.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683982809319431260-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 5.png
# back
# 291 , 504
# 301 , 500
# 295 , 511
# 306 , 507
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 3.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 6.png
# front
# 110 , 667
# 129 , 680
# 105 , 687
# 125 , 705
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683108011603015572-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 6.png
# front
# 467 , 509
# 481 , 503
# 473 , 523
# 489 , 515
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 5.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 5.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 2.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683439209638457891-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# front
# 78 , 555
# 84 , 552
# 81 , 562
# 90 , 558
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_square.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1685484008793292624-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# back
# 1130 , 474
# 1146 , 474
# 1129 , 482
# 1145 , 483
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 3.png
# back
# 261 , 471
# 278 , 474
# 259 , 482
# 276 , 486
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1685170808633899309-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_square.png
# back
# 89 , 552
# 98 , 548
# 93 , 562
# 103 , 557
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# back
# 698 , 330
# 707 , 330
# 699 , 334
# 709 , 335
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 4.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683028810401833816-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy.png
# back
# 960 , 303
# 970 , 300
# 968 , 308
# 979 , 304
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy.png
# front
# 1262 , 732
# 1265 , 743
# 1250 , 734
# 1251 , 744
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 2.png
# front
# 75 , 317
# 73 , 293
# 104 , 315
# 99 , 291
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684479609577395896-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 4.png
# front
# 941 , 248
# 947 , 246
# 944 , 255
# 952 , 253
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 4.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 2.png
# front
# 103 , 754
# 96 , 727
# 138 , 750
# 133 , 725
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1685304010020704936-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_square.png
# back
# 401 , 527
# 412 , 522
# 405 , 536
# 417 , 530
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 6.png
# front
# 714 , 314
# 723 , 315
# 714 , 321
# 723 , 323
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 5.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 4.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684314009634771017-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_square.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 3.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683594009899488370-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 2.png
# front
# 1152 , 420
# 1166 , 420
# 1147 , 430
# 1165 , 432
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# front
# 505 , 494
# 521 , 496
# 501 , 508
# 520 , 511
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle2.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1682992807714060933-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle2.png
# front
# 884 , 377
# 891 , 373
# 891 , 383
# 898 , 378
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U2.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 5.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684695610048302737-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U2.png
# front
# 839 , 362
# 848 , 357
# 845 , 371
# 856 , 365
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 4.png
# back
# 539 , 379
# 550 , 381
# 537 , 388
# 550 , 391
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U2.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 4.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684112409447327150-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U2.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_square.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1685106009601777837-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_emblem.png
# back
# 812 , 375
# 822 , 370
# 816 , 380
# 827 , 376
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U.png
# front
# 721 , 460
# 733 , 459
# 728 , 471
# 741 , 471
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683554410225278071-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 6.png
# back
# 807 , 614
# 820 , 618
# 800 , 623
# 813 , 630
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 3.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_square.png
# front
# 158 , 508
# 184 , 524
# 144 , 530
# 171 , 549
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684580409010625132-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber.png
# back
# 1176 , 611
# 1180 , 617
# 1167 , 613
# 1169 , 621
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 4.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683079210534049853-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 3.png
# back
# 661 , 557
# 675 , 551
# 666 , 570
# 685 , 562
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 4.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683014409400101768-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 2.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 5.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683291609562833709-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U2.png
# back
# 60 , 575
# 70 , 571
# 64 , 585
# 74 , 580
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 3.png
# front
# 985 , 607
# 997 , 612
# 980 , 619
# 995 , 626
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle2.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684731609318604072-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# front
# 81 , 573
# 88 , 570
# 84 , 579
# 92 , 575
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 5.png
# front
# 694 , 319
# 701 , 321
# 691 , 324
# 699 , 326
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 6.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684263609728018089-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# back
# 171 , 493
# 176 , 491
# 172 , 498
# 179 , 495
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# front
# 314 , 749
# 324 , 743
# 323 , 761
# 335 , 753
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 2.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1685102409551065957-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_square.png
# front
# 653 , 472
# 664 , 467
# 658 , 482
# 671 , 475
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle2.png
# front
# 1208 , 715
# 1209 , 721
# 1200 , 716
# 1202 , 723
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U2.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684782009072408574-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# back
# 747 , 583
# 762 , 577
# 753 , 591
# 768 , 584
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U.png
# back
# 1134 , 551
# 1145 , 554
# 1128 , 562
# 1142 , 568
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683529209918062800-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 4.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684209608935127444-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 4.png
# back
# 761 , 264
# 768 , 261
# 766 , 270
# 774 , 266
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber.png
# front
# 957 , 567
# 972 , 567
# 960 , 584
# 977 , 583
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684540809251333246-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# front
# 259 , 348
# 267 , 344
# 265 , 352
# 271 , 349
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683327610608148923-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_square.png
# front
# 903 , 258
# 910 , 256
# 907 , 263
# 914 , 260
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U2.png
# front
# 541 , 807
# 533 , 821
# 523 , 807
# 515 , 818
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U.png
# front
# 41 , 712
# 38 , 695
# 61 , 708
# 56 , 693
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 6.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1685469608868635192-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 2.png
# back
# 920 , 591
# 934 , 584
# 931 , 604
# 944 , 595
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber.png
# front
# 94 , 361
# 98 , 366
# 87 , 366
# 89 , 372
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 5.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 5.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684296009240069633-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 6.png
# back
# 107 , 582
# 117 , 576
# 110 , 591
# 122 , 585
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_emblem.png
# front
# 964 , 476
# 974 , 480
# 962 , 481
# 973 , 485
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_square.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1685030409583269654-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# front
# 120 , 584
# 127 , 581
# 123 , 591
# 131 , 587
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# back
# 754 , 738
# 772 , 745
# 752 , 748
# 771 , 755
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# back
# 245 , 674
# 240 , 654
# 258 , 672
# 254 , 656
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 3.png
# front
# 1168 , 90
# 1173 , 106
# 1149 , 97
# 1154 , 113
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684360808354660449-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_emblem.png
# back
# 404 , 524
# 417 , 518
# 408 , 531
# 421 , 525
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 6.png
# front
# 483 , 444
# 494 , 448
# 480 , 452
# 490 , 456
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 5.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683619209384996884-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U2.png
# front
# 1173 , 720
# 1184 , 724
# 1170 , 732
# 1182 , 737
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 2.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 3.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684170011030197593-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 3.png
# back
# 723 , 384
# 731 , 380
# 729 , 394
# 738 , 387
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 6.png
# back
# 706 , 351
# 715 , 353
# 705 , 359
# 715 , 362
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle2.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_square.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1685455210532140206-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 2.png
# front
# 428 , 511
# 440 , 505
# 436 , 525
# 452 , 515
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_emblem.png
# front
# 553 , 360
# 562 , 363
# 551 , 364
# 561 , 368
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber.png
# back
# 1127 , 98
# 1127 , 118
# 1109 , 100
# 1110 , 120
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684702809625338350-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 3.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 4.png
# front
# 900 , 810
# 905 , 798
# 912 , 819
# 918 , 805
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# back
# 434 , 517
# 429 , 498
# 449 , 515
# 444 , 496
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 6.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1685120409787395464-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 2.png
# front
# 423 , 365
# 433 , 367
# 423 , 374
# 433 , 376
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683068409559063392-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 2.png
# back
# 405 , 436
# 415 , 432
# 409 , 444
# 420 , 440
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy.png
# front
# 721 , 320
# 727 , 320
# 721 , 326
# 729 , 327
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle2.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 3.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684922409403459390-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U2.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683489609266131614-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# front
# 1141 , 645
# 1153 , 639
# 1150 , 654
# 1162 , 648
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# back
# 611 , 385
# 625 , 388
# 611 , 391
# 627 , 395
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_square.png
# front
# 70 , 293
# 67 , 276
# 94 , 293
# 91 , 275
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1685156409905824204-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# front
# 593 , 438
# 602 , 433
# 599 , 446
# 609 , 439
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_emblem.png
# back
# 241 , 537
# 257 , 542
# 240 , 543
# 255 , 548
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle2.png
# back
# 392 , 411
# 406 , 421
# 385 , 423
# 399 , 434
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle2.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684810808692712316-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 5.png
# back
# 125 , 599
# 134 , 594
# 128 , 608
# 140 , 602
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_emblem.png
# back
# 927 , 453
# 935 , 452
# 930 , 457
# 938 , 457
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_emblem.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683356409499379224-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_emblem.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684407608945708877-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 3.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 3.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 5.png
# back
# 218 , 576
# 215 , 555
# 242 , 574
# 235 , 554
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684706410502581953-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 4.png
# front
# 1180 , 319
# 1190 , 318
# 1181 , 326
# 1193 , 326
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# back
# 627 , 378
# 636 , 380
# 625 , 382
# 636 , 385
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 5.png
# back
# 722 , 100
# 747 , 108
# 718 , 119
# 746 , 131
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_square.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683435609260363335-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_square.png
# back
# 409 , 518
# 420 , 513
# 415 , 527
# 427 , 521
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy.png
# back
# 769 , 435
# 781 , 437
# 769 , 446
# 782 , 448
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 6.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_square.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684252807928882046-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 5.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 3.png
# back
# 324 , 764
# 338 , 753
# 340 , 780
# 354 , 762
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_square.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_emblem.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1685149208907181492-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 2.png
# front
# 736 , 265
# 742 , 263
# 740 , 269
# 747 , 267
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_square.png
# back
# 660 , 353
# 669 , 354
# 658 , 360
# 668 , 363
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_square.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_emblem.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684015208316105749-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_emblem.png
# front
# 641 , 452
# 652 , 447
# 645 , 458
# 658 , 453
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy.png
# back
# 672 , 275
# 679 , 276
# 670 , 280
# 679 , 283
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683154809546123172-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U2.png
# back
# 986 , 601
# 1003 , 595
# 1000 , 617
# 1015 , 609
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 4.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 4.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 5.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683486008950636905-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle2.png
# front
# 412 , 538
# 418 , 535
# 416 , 543
# 423 , 539
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_emblem.png
# back
# 721 , 357
# 730 , 357
# 722 , 362
# 733 , 362
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683392410986328289-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# back
# 400 , 520
# 410 , 517
# 402 , 525
# 414 , 521
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 3.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683313209369491953-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 2.png
# back
# 778 , 258
# 784 , 256
# 780 , 264
# 787 , 261
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_emblem.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 4.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle2.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683536409435873686-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 5.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 3.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1683244809115823075-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# front
# 500 , 451
# 507 , 448
# 504 , 457
# 512 , 454
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber.png
# back
# 728 , 374
# 737 , 374
# 731 , 383
# 740 , 382
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/lyft_square.png
# back
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1684857608525704161-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy.png
# front
# 914 , 370
# 925 , 366
# 922 , 382
# 935 , 375
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# back
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 2.png
# front
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# front
# IMAGES:  /home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3ae33b/1685516409431086803-sample.jpg
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 2.png
# front
# 470 , 535
# 484 , 530
# 479 , 547
# 494 , 541
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle2.png
# back

# %%
# Divide image from Waggle Node W026 into quadrants and overlay sticker on picture - testing code for one picture

import os
from os import listdir
import glob

 
# get the path/directory
#for images in os.listdir(folder_dir):

count = 0
images = '/home/tiwari/Waggle-Private Folder/storage.sagecontinuum.org/api/v1/data/imagesampler-bottom/sage-imagesampler-bottom-0.3.0/000048b02d3af41e/1682985618479732991-sample.jpg'
car = cv2.imread(images)
(h, w) = car.shape[:2]
(center_x, center_y) = (w//2, h//2)

# Divide image into 4 quadrants
top_left = car[0:(center_y//2), 0:(center_x//2)]
top_right = car[0:center_y, center_x:w]
bot_left = car[center_y:h, 0:center_x]
bot_right = car[center_y:h, center_x:w]
global pts

for i in range(4):
    # Store quadrant images as new file, call SetSticker function to overlay sticker in each quadrant
    if i == 0:
        cv2.imwrite(str(count)+"q1.jpeg", top_left)
        overlay = setSticker(str(count) + "q1.jpeg")
        if (len(overlay) > 0):
            Image.fromarray(overlay).save(str(count) + "q1.jpeg")

    elif i ==1:
        pts = []
        cv2.imwrite(str(count)+'q2.jpeg', top_right)
        overlay = setSticker(str(count) + "q2.jpeg")
        if (len(overlay) >0):
            Image.fromarray(overlay).save(str(count) + "q2.jpeg")

    elif i ==2:
        pts = []
        cv2.imwrite(str(count)+'q3.jpeg', bot_left)

        overlay = setSticker(str(count) + "q3.jpeg")
        if (len(overlay) > 0):
            Image.fromarray(overlay).save(str(count) + "q3.jpeg")

    else:
        pts = []
        cv2.imwrite(str(count)+'q4.jpeg', bot_right)
        overlay = setSticker(str(count) + "q4.jpeg")
        if (len(overlay) > 0):
            Image.fromarray(overlay).save(str(count) + "q4.jpeg")

count += 1
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Circle3.png
# front
# 422 , 341
# 440 , 338
# 427 , 347
# 438 , 348
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Sticker.png
# front
# 222 , 205
# 374 , 225
# 204 , 353
# 418 , 372
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_Logo4.png
# back
# 340 , 246
# 567 , 251
# 398 , 435
# 653 , 425
# /home/tiwari/Waggle-Private Folder/Ridesharing Stickers/Uber_U2.png
# front
# 384 , 248
# 492 , 341
# 399 , 467
# 720 , 521

# %%
cv2.destroyAllWindows()

# %%
import cv2

# read the input image
sticker = cv2.imread("/home/tiwari/Waggle-Private Folder/Ridesharing Stickers/airport-uber copy 2.png")

# define the alpha and beta
alpha = 0.75 # Contrast control
beta = 1 # Brightness control

# call convertScaleAbs function
adjusted = cv2.convertScaleAbs(sticker, alpha=alpha, beta=beta)

# display the output image
cv2.imshow('adjusted', adjusted)
cv2.waitKey()
cv2.destroyAllWindows()
