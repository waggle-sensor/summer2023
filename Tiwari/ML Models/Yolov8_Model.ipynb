# %% [markdown]
# ###Training a YoloV8 Model with Custom Data

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.4/612.4 kB 30.6 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data= /content/drive/MyDrive/yolov7/yolov7/data/coco.yaml epochs=30 device=0
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !cp -r "/content/runs_2" "/content/drive/MyDrive"

# %%
# !yolo task=detect mode=val model="/content/runs/detect/train2/weights/best.pt" data="/content/drive/MyDrive/yolov7/yolov7/data/coco.yaml" device=0
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/yolov7/yolov7/data/val... 587 images, 468 backgrounds, 0 corrupt: 100% 587/587 [00:01<00:00, 302.98it/s]
# val: New cache created: /content/drive/MyDrive/yolov7/yolov7/data/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 37/37 [00:14<00:00,  2.57it/s]
#                    all        587        128      0.804      0.803      0.849      0.423
# Speed: 0.9ms preprocess, 4.5ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to runs/detect/val2

# %%
# !yolo task=detect mode=predict model='/content/drive/MyDrive/runs/detect/train2/weights/best.pt' source='/content/drive/MyDrive/cartest_final.jpg' device=0
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/cartest_final.jpg: 480x640 1 rideshare, 52.6ms
# Speed: 12.7ms preprocess, 52.6ms inference, 18.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %% [markdown]
# Epochs: 30
# <br> May need to run for additional epochs to improve precision and recall, but this is a promising first start!

# %% [markdown]
# #### Stage 2
# Running model again for 30 epochs using previous 30-epoch trained custom weight

# %%
# !yolo task=detect mode=train model='/content/drive/MyDrive/runs/detect/train2/weights/best.pt' data= /content/drive/MyDrive/yolov7/yolov7/data/coco.yaml epochs=30 device=0
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model= '/content/runs/detect/train/weights/best.pt' data="/content/drive/MyDrive/yolov7/yolov7/data/coco.yaml" device=0
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/yolov7/yolov7/data/val... 587 images, 468 backgrounds, 0 corrupt: 100% 587/587 [00:03<00:00, 191.84it/s]
# val: New cache created: /content/drive/MyDrive/yolov7/yolov7/data/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 37/37 [00:13<00:00,  2.83it/s]
#                    all        587        128      0.834      0.787      0.833      0.425
# Speed: 0.8ms preprocess, 4.6ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to runs/detect/val

# %%
# !yolo task=detect mode=predict model='/content/runs_2/detect/train/weights/best.pt' source='/content/drive/MyDrive/cartest_final.jpg' device=0
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/cartest_final.jpg: 480x640 (no detections), 51.7ms
# Speed: 2.1ms preprocess, 51.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
# !rm -rf '/content/runs'

# %% [markdown]
# #### Stage 3
# Running model again for 30 epochs using previous 30-epoch trained custom weight from Stage 2
# <br> EDIT: DECREASED accuracy - unused in final model

# %%
# !yolo task=detect mode=train model='/content/drive/MyDrive/runs_2/detect/train/weights/best.pt' data= /content/drive/MyDrive/yolov7/yolov7/data/coco.yaml epochs=30 device=0
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model= '/content/runs/detect/train/weights/best.pt' data="/content/drive/MyDrive/yolov7/yolov7/data/coco.yaml" device=0
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/yolov7/yolov7/data/val... 587 images, 468 backgrounds, 0 corrupt: 100% 587/587 [00:02<00:00, 206.97it/s]
# val: New cache created: /content/drive/MyDrive/yolov7/yolov7/data/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 37/37 [00:12<00:00,  3.02it/s]
#                    all        587        128      0.762      0.766       0.81       0.41
# Speed: 1.5ms preprocess, 4.6ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to runs/detect/val

# %% [markdown]
# ### Approach 2: Training training data for 300 epochs (patience = 50 epochs)

# %%
# !yolo task=detect mode=train model=yolov8n.pt data= /content/drive/MyDrive/yolov7/yolov7/data/coco.yaml epochs=300 device=0
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 77.8MB/s]
# Ultralytics YOLOv8.0.123 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model= '/content/drive/MyDrive/last-4.pt' data="/content/drive/MyDrive/yolov7/yolov7/data/coco.yaml" device=0
# Out:
# Ultralytics YOLOv8.0.123 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
# ...
# 100% 755k/755k [00:00<00:00, 113MB/s]
# val: Scanning /content/drive/MyDrive/yolov7/yolov7/data/val... 587 images, 468 backgrounds, 0 corrupt: 100% 587/587 [00:17<00:00, 32.84it/s]
# val: New cache created: /content/drive/MyDrive/yolov7/yolov7/data/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 37/37 [00:15<00:00,  2.46it/s]
#                    all        587        128      0.837      0.805       0.89      0.427
# Speed: 1.0ms preprocess, 4.0ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to runs/detect/val

# %%
# !yolo task=detect mode=predict model='/content/drive/MyDrive/last-4.pt' source='/content/drive/MyDrive/cartest_final.jpg' device=0
# Out:
# Ultralytics YOLOv8.0.123 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/cartest_final.jpg: 480x640 (no detections), 50.4ms
# Speed: 2.2ms preprocess, 50.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict

# %%
# !cp -r "/content/runs_final" "/content/drive/MyDrive"

# %% [markdown]
# Final Conclusions: 170 YoloV8 model (pretrained with COCO dataset yolov8n.pt weights) showed slightly better recall and precision than previous model with 2-stage 30-epoch trained model.
