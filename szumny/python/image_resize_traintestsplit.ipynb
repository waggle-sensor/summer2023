# %%
import keras,os
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import random
from PIL import Image
# Out:
# 2023-06-08 14:33:27.792878: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-08 14:33:29.567026: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-08 14:33:29.580206: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 14:33:53.455297: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
directory = '/home/jszumny/Documents/copy of smoke data/hpwren/newnew/smoke/'

# image = Image.open(directory + "smoke_85.jpg")

# new_image = image.resize((224, 224))
# new_image
sum = 0
for filename in os.listdir(directory):
    print(filename)
sum
# Out:
# 20200601_WILDLAND-DRILLS_mlo-e-mobo-c_1591045821_+01080_sbb_smoke.jpg
# 20180602_Alison_sp-w-mobo-c_1527970472_+00480_sbb_smoke.jpg
# 20180827_Holyflareup_sp-e-mobo-c_1535383888_+00420_sbb_smoke.jpg
# 20170713_FIRE_smer-tcs8-mobo-c_1499982115_+01080_sbb_smoke.jpg
# 20190610_FIRE_bh-w-mobo-c_1560200356_+02220_sbb_smoke.jpg
# 20200521_VEGMGMT_wc-e-mobo-c_1590082580_+01620_sbb_smoke.jpg
# 20190930_FIRE_om-s-mobo-c_1569877899_+00896_sbb_smoke.jpg
# 20200202_FIRE_hp-w-mobo-c_1580670031_+02040_sbb_smoke.jpg
# 20180728_FIRE_smer-tcs9-mobo-c_1532816457_+00420_sbb_smoke.jpg
# 20170519_FIRE_rm-w-mobo-c_1495226646_+00360_sbb_smoke.jpg
# 20180603_FIRE_smer-tcs9-mobo-c_1528057437_+00120_sbb_smoke.jpg
# 20190715_MLOSouth1_lo-s-mobo-c_1563217583_+00840_sbb_smoke.jpg
# 20191006_FIRE_lo-w-mobo-c_1570385365_+01080_sbb_smoke.jpg
# 20180614_Bridle_hp-n-mobo-c_1529022865_+02160_sbb_smoke.jpg
# 20171017_FIRE_smer-tcs3-mobo-c_1508276408_+01080_sbb_smoke.jpg
# ...

# %%
for filename in os.listdir(directory):
    image = Image.open(directory + filename)
    new_image = image.resize((224, 224))
    new_image.save(directory + filename)

# %%
for i in range(9871):
    image = Image.open(directory + "smoke_" + str(i) + ".jpg")
    choice = random.choice([0, 0, 0, 0, 0, 0, 0, 2, 2, 1])
    if choice == 0:
        new_image = image.resize((224, 224))
        new_image.save('/home/jszumny/Documents/copy of smoke data/hpwren/modeldata/train/smoke/smoke_resized' + str(i) + ".jpg")
    if choice == 1:
        new_image = image.resize((224, 224))
        new_image.save('/home/jszumny/Documents/copy of smoke data/hpwren/modeldata/test/smoke/smoke_resized' + str(i) + ".jpg")
    if choice == 2:
        new_image = image.resize((224, 224))
        new_image.save('/home/jszumny/Documents/copy of smoke data/hpwren/modeldata/val/smoke/smoke_resized' + str(i) + ".jpg")

# %%
directory = '/home/jszumny/Documents/copy of smoke data/hpwren/newdata/cropped sky images/'
for i in range(1000):
    for j in range(3):
        for k in range(3):
            image = Image.open(directory + "sky" + str(i) + "_0" + str(j+1) + "_0" + str(k+1) + ".jpg")
            choice = random.choice([0, 0, 0, 0, 0, 0, 0, 2, 2, 1])
            if choice == 0:
                new_image = image.resize((224, 224))
                new_image.save('/home/jszumny/Documents/copy of smoke data/hpwren/modeldata/train/sky/sky_resized' + str(i) + "_" + str(j) + "_" + str(k) + ".jpg")
            if choice == 1:
                new_image = image.resize((224, 224))
                new_image.save('/home/jszumny/Documents/copy of smoke data/hpwren/modeldata/test/sky/sky_resized' + str(i) + "_" + str(j) + "_" + str(k) + ".jpg")
            if choice == 2:
                new_image = image.resize((224, 224))
                new_image.save('/home/jszumny/Documents/copy of smoke data/hpwren/modeldata/val/sky/sky_resized' + str(i) + "_" + str(j) + "_" + str(k) + ".jpg")

# %%
directory = '/home/jszumny/Documents/copy of smoke data/hpwren/newdata/cropped ground images/'
for i in range(1000):
    for j in range(3):
        for k in range(3):
            image = Image.open(directory + "ground" + str(i) + "_0" + str(j+1) + "_0" + str(k+1) + ".jpg")
            choice = random.choice([0, 0, 0, 0, 0, 0, 0, 2, 2, 1])
            if choice == 0:
                new_image = image.resize((224, 224))
                new_image.save('/home/jszumny/Documents/copy of smoke data/hpwren/modeldata/train/ground/ground_resized' + str(i) + "_" + str(j) + "_" + str(k) + ".jpg")
            if choice == 1:
                new_image = image.resize((224, 224))
                new_image.save('/home/jszumny/Documents/copy of smoke data/hpwren/modeldata/test/ground/ground_resized' + str(i) + "_" + str(j) + "_" + str(k) + ".jpg")
            if choice == 2:
                new_image = image.resize((224, 224))
                new_image.save('/home/jszumny/Documents/copy of smoke data/hpwren/modeldata/val/ground/ground_resized' + str(i) + "_" + str(j) + "_" + str(k) + ".jpg")
