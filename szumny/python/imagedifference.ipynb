# %%
import cv2
import numpy as np
from PIL import Image

# %%
img1 = cv2.imread('/home/jszumny/Documents/test/34.jpg')
img2 = cv2.imread('/home/jszumny/Documents/test/34f.jpg')
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# %%
def mse(img1, img2):
   h, w = img1.shape
   diff = cv2.subtract(img1, img2)
   err = np.sum(diff**2)
   mse = err/(float(h*w))
   return mse, diff

# %%
error = mse(img1, img2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3056809/1634319704.py in <module>
# ----> 1 error = mse(img1, img2)
#
# NameError: name 'mse' is not defined

# %%
def mse(img1, img2):
   h, w = img1.shape
   diff = cv2.subtract(img1, img2)
   err = np.sum(diff**2)
   mse = err/(float(h*w))
   return mse, diff

error, diff = mse(img1, img2)
print("Image matching Error between the two images:",error)

cv2.imwrite("/home/jszumny/Documents/test/difference.jpg", diff)
# Out:
# Image matching Error between the two images: 37.92490433673469
# True

# %%
img1 = cv2.imread('/home/jszumny/Documents/test/00.jpg')
img2 = cv2.imread('/home/jszumny/Documents/test/00f.jpg')
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

error, diff = mse(img1, img2)
print("Image matching Error between the two images:",error)

cv2.imwrite("/home/jszumny/Documents/test/difference.jpg", diff)
# Out:
# Image matching Error between the two images: 47.455436862244895
# True

# %%
fullimage = Image.open("/home/jszumny/Arm Data/enatwrcamtarmacC1.a1.20221001.001123.jpg/enatwrcamtarmacC1.a1.20221001.145923.jpg")
fullimage = fullimage.resize((2688, 2240))

for i in range(12):
    for k in range(10):
        
        tile = fullimage.crop((i*224, k*224, (i+1)*224, (k+1)*224))
        tile.save('/home/jszumny/Documents/test/' + str(i) + str(k) + '.jpg')

# %%
fullimage = Image.open("/home/jszumny/Arm Data/enatwrcamtarmacC1.a1.20221001.001123.jpg/enatwrcamtarmacC1.a1.20221001.150023.jpg")
fullimage = fullimage.resize((2688, 2240))

for i in range(12):
    for k in range(10):
        
        tile = fullimage.crop((i*224, k*224, (i+1)*224, (k+1)*224))
        tile.save('/home/jszumny/Documents/test/' + str(i) + str(k) + 'f.jpg')

# %%
import os

dir = "/home/jszumny/Documents/copy of smoke data/newnew/smoke/"

list = []
for file in sorted(os.listdir(dir)):
    if file not in list:
        list.append(file)
list
# Out:
# ['20160604_FIRE_rm-n-mobo-c_1465065600_+00000_ipbb_smoke.jpg',
#  '20160604_FIRE_rm-n-mobo-c_1465065600_+00000_sbb_smoke.jpg',
#  '20160604_FIRE_rm-n-mobo-c_1465065660_+00060_ipbb_smoke.jpg',
#  '20160604_FIRE_rm-n-mobo-c_1465065660_+00060_sbb_smoke.jpg',
#  '20160604_FIRE_rm-n-mobo-c_1465065720_+00120_ipbb_smoke.jpg',
#  '20160604_FIRE_rm-n-mobo-c_1465065720_+00120_sbb_smoke.jpg',
#  '20160604_FIRE_rm-n-mobo-c_1465065780_+00180_ipbb_smoke.jpg',
#  '20160604_FIRE_rm-n-mobo-c_1465065780_+00180_sbb_smoke.jpg',
#  '20160604_FIRE_rm-n-mobo-c_1465065840_+00240_ipbb_smoke.jpg',
#  '20160604_FIRE_rm-n-mobo-c_1465065840_+00240_lpbb_smoke.jpg',
#  '20160604_FIRE_rm-n-mobo-c_1465065840_+00240_sbb_smoke.jpg',
#  '20160604_FIRE_rm-n-mobo-c_1465065900_+00300_ipbb_smoke.jpg',
#  '20160604_FIRE_rm-n-mobo-c_1465065900_+00300_lpbb_smoke.jpg',
#  '20160604_FIRE_rm-n-mobo-c_1465065900_+00300_sbb_smoke.jpg',
#  '20160604_FIRE_rm-n-mobo-c_1465065960_+00360_ipbb_smoke.jpg',
# ...

# %%
for i in range(len(list)):
    if "sbb" in list[i] and "+00000" not in list[i]:
        if list[i][0:25] == list[i-1][0:25]:

            img1 = cv2.imread(dir + list[i])
            img2 = cv2.imread(dir + list[i-1])
            img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
            img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

            error, diff = mse(img1, img2)

            cv2.imwrite("/home/jszumny/Documents/copy of smoke data/newnew/diffsmoke/" + list[i], diff)

# %%
for i in range(len(list)):
    if "ipbb" in list[i] and "+00000" not in list[i]:
        if list[i][0:25] == list[i-1][0:25]:

            img1 = cv2.imread(dir + list[i])
            img2 = cv2.imread(dir + list[i-1])
            img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
            img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

            error, diff = mse(img1, img2)

            cv2.imwrite("/home/jszumny/Documents/copy of smoke data/newnew/diffsmoke/" + list[i], diff)

# %%
for i in range(len(list)):
    if "lpbb" in list[i] and "+00000" not in list[i]:
        if list[i][0:25] == list[i-1][0:25]:

            img1 = cv2.imread(dir + list[i])
            img2 = cv2.imread(dir + list[i-1])
            img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
            img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

            error, diff = mse(img1, img2)

            cv2.imwrite("/home/jszumny/Documents/copy of smoke data/newnew/diffsmoke/" + list[i], diff)

# %%
dir = "/home/jszumny/Documents/copy of smoke data/newnew/SWIMxxx/swinyseg/images/"

list = []
for file in sorted(os.listdir(dir)):
    if file not in list and "_" not in file:
        list.append(file)
list
# Out:
# ['d0001.jpg',
#  'd0002.jpg',
#  'd0003.jpg',
#  'd0004.jpg',
#  'd0005.jpg',
#  'd0006.jpg',
#  'd0007.jpg',
#  'd0008.jpg',
#  'd0009.jpg',
#  'd0010.jpg',
#  'd0011.jpg',
#  'd0012.jpg',
#  'd0013.jpg',
#  'd0014.jpg',
#  'd0015.jpg',
#  'd0016.jpg',
#  'd0017.jpg',
#  'd0018.jpg',
#  'd0019.jpg',
#  'd0020.jpg',
#  'd0021.jpg',
#  'd0022.jpg',
#  'd0023.jpg',
#  'd0024.jpg',
#  'd0025.jpg',
#  'd0026.jpg',
#  'd0027.jpg',
#  'd0028.jpg',
#  'd0029.jpg',
#  'd0030.jpg',
#  'd0031.jpg',
#  'd0032.jpg',
#  'd0033.jpg',
#  'd0034.jpg',
#  'd0035.jpg',
#  'd0036.jpg',
#  'd0037.jpg',
#  'd0038.jpg',
#  'd0039.jpg',
#  'd0040.jpg',
#  'd0041.jpg',
#  'd0042.jpg',
#  'd0043.jpg',
#  'd0044.jpg',
#  'd0045.jpg',
#  'd0046.jpg',
#  'd0047.jpg',
#  'd0048.jpg',
#  'd0049.jpg',
#  'd0050.jpg',
#  'd0051.jpg',
#  'd0052.jpg',
#  'd0053.jpg',
#  'd0054.jpg',
#  'd0055.jpg',
#  'd0056.jpg',
#  'd0057.jpg',
#  'd0058.jpg',
#  'd0059.jpg',
#  'd0060.jpg',
#  'd0061.jpg',
#  'd0062.jpg',
# ...

# %%
for i in range(len(list)):
    if "d0001" not in list[i]:
        img1 = cv2.imread(dir + list[i])
        img2 = cv2.imread(dir + list[i-1])
        img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

        error, diff = mse(img1, img2)

        cv2.imwrite("/home/jszumny/Documents/copy of smoke data/newnew/diffcloud/" + list[i], diff)

# %%
dir = "/home/jszumny/Documents/copy of smoke data/newnew/SWIMxxx/swimcat/B-pattern/images/"

list = []
for file in sorted(os.listdir(dir)):
    if file not in list:
        list.append(file)
list
# Out:
# ['B_10img.png',
#  'B_11img.png',
#  'B_12img.png',
#  'B_13img.png',
#  'B_14img.png',
#  'B_15img.png',
#  'B_16img.png',
#  'B_17img.png',
#  'B_18img.png',
#  'B_19img.png',
#  'B_1img.png',
#  'B_20img.png',
#  'B_21img.png',
#  'B_22img.png',
#  'B_23img.png',
#  'B_24img.png',
#  'B_25img.png',
#  'B_26img.png',
#  'B_27img.png',
#  'B_28img.png',
#  'B_29img.png',
#  'B_2img.png',
#  'B_30img.png',
#  'B_31img.png',
#  'B_32img.png',
#  'B_33img.png',
#  'B_34img.png',
#  'B_35img.png',
#  'B_36img.png',
#  'B_37img.png',
#  'B_38img.png',
#  'B_39img.png',
#  'B_3img.png',
#  'B_40img.png',
#  'B_41img.png',
#  'B_42img.png',
#  'B_43img.png',
#  'B_44img.png',
#  'B_45img.png',
#  'B_46img.png',
#  'B_47img.png',
#  'B_48img.png',
#  'B_49img.png',
#  'B_4img.png',
#  'B_50img.png',
#  'B_51img.png',
#  'B_52img.png',
#  'B_53img.png',
#  'B_54img.png',
#  'B_55img.png',
#  'B_56img.png',
#  'B_57img.png',
#  'B_58img.png',
#  'B_59img.png',
#  'B_5img.png',
# ...

# %%
for i in range(len(list)):
    if "B_10img" not in list[i]:
        img1 = cv2.imread(dir + list[i])
        img2 = cv2.imread(dir + list[i-1])
        img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

        error, diff = mse(img1, img2)

        cv2.imwrite("/home/jszumny/Documents/copy of smoke data/newnew/diffcloud/" + list[i], diff)

# %%
dir = "/home/jszumny/Documents/copy of smoke data/newnew/SWIMxxx/swimcat/C-thick-dark/images/"

list = []
for file in sorted(os.listdir(dir)):
    if file not in list:
        list.append(file)
list
# Out:
# ['C_100img.png',
#  'C_101img.png',
#  'C_102img.png',
#  'C_103img.png',
#  'C_104img.png',
#  'C_105img.png',
#  'C_106img.png',
#  'C_107img.png',
#  'C_108img.png',
#  'C_109img.png',
#  'C_10img.png',
#  'C_110img.png',
#  'C_111img.png',
#  'C_112img.png',
#  'C_113img.png',
#  'C_114img.png',
#  'C_115img.png',
#  'C_116img.png',
#  'C_117img.png',
#  'C_118img.png',
#  'C_119img.png',
#  'C_11img.png',
#  'C_120img.png',
#  'C_121img.png',
#  'C_122img.png',
#  'C_123img.png',
#  'C_124img.png',
#  'C_125img.png',
#  'C_126img.png',
#  'C_127img.png',
#  'C_128img.png',
#  'C_129img.png',
#  'C_12img.png',
#  'C_130img.png',
#  'C_131img.png',
#  'C_132img.png',
#  'C_133img.png',
#  'C_134img.png',
#  'C_135img.png',
#  'C_136img.png',
#  'C_137img.png',
#  'C_138img.png',
#  'C_139img.png',
#  'C_13img.png',
#  'C_140img.png',
#  'C_141img.png',
#  'C_142img.png',
#  'C_143img.png',
#  'C_144img.png',
#  'C_145img.png',
#  'C_146img.png',
#  'C_147img.png',
# ...

# %%
for i in range(len(list)):
    if "C_100img" not in list[i]:
        img1 = cv2.imread(dir + list[i])
        img2 = cv2.imread(dir + list[i-1])
        img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

        error, diff = mse(img1, img2)

        cv2.imwrite("/home/jszumny/Documents/copy of smoke data/newnew/diffcloud/" + list[i], diff)

# %%
dir = "/home/jszumny/Documents/copy of smoke data/newnew/SWIMxxx/swimcat/D-thick-white/images/"

list = []
for file in sorted(os.listdir(dir)):
    if file not in list:
        list.append(file)
list
# Out:
# ['D_100img.png',
#  'D_101img.png',
#  'D_102img.png',
#  'D_103img.png',
#  'D_104img.png',
#  'D_105img.png',
#  'D_106img.png',
#  'D_107img.png',
#  'D_108img.png',
#  'D_109img.png',
#  'D_10img.png',
#  'D_110img.png',
#  'D_111img.png',
#  'D_112img.png',
#  'D_113img.png',
#  'D_114img.png',
#  'D_115img.png',
#  'D_116img.png',
#  'D_117img.png',
#  'D_118img.png',
#  'D_119img.png',
#  'D_11img.png',
#  'D_120img.png',
#  'D_121img.png',
#  'D_122img.png',
#  'D_123img.png',
#  'D_124img.png',
#  'D_125img.png',
#  'D_126img.png',
#  'D_127img.png',
#  'D_128img.png',
#  'D_129img.png',
#  'D_12img.png',
#  'D_130img.png',
#  'D_131img.png',
#  'D_132img.png',
#  'D_133img.png',
#  'D_134img.png',
#  'D_135img.png',
#  'D_13img.png',
#  'D_14img.png',
#  'D_15img.png',
#  'D_16img.png',
#  'D_17img.png',
#  'D_18img.png',
#  'D_19img.png',
#  'D_1img.png',
#  'D_20img.png',
#  'D_21img.png',
#  'D_22img.png',
#  'D_23img.png',
#  'D_24img.png',
#  'D_25img.png',
# ...

# %%
for i in range(len(list)):
    if "D_100img" not in list[i]:
        img1 = cv2.imread(dir + list[i])
        img2 = cv2.imread(dir + list[i-1])
        img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

        error, diff = mse(img1, img2)

        cv2.imwrite("/home/jszumny/Documents/copy of smoke data/newnew/diffcloud/" + list[i], diff)

# %%
dir = "/home/jszumny/Documents/copy of smoke data/newnew/SWIMxxx/swimcat/E-veil/images/"

list = []
for file in sorted(os.listdir(dir)):
    if file not in list:
        list.append(file)
list
# Out:
# ['E_10img.png',
#  'E_11img.png',
#  'E_12img.png',
#  'E_13img.png',
#  'E_14img.png',
#  'E_15img.png',
#  'E_16img.png',
#  'E_17img.png',
#  'E_18img.png',
#  'E_19img.png',
#  'E_1img.png',
#  'E_20img.png',
#  'E_21img.png',
#  'E_22img.png',
#  'E_23img.png',
#  'E_24img.png',
#  'E_25img.png',
#  'E_26img.png',
#  'E_27img.png',
#  'E_28img.png',
#  'E_29img.png',
#  'E_2img.png',
#  'E_30img.png',
#  'E_31img.png',
#  'E_32img.png',
#  'E_33img.png',
#  'E_34img.png',
#  'E_35img.png',
#  'E_36img.png',
#  'E_37img.png',
#  'E_38img.png',
#  'E_39img.png',
#  'E_3img.png',
#  'E_40img.png',
#  'E_41img.png',
#  'E_42img.png',
#  'E_43img.png',
#  'E_44img.png',
#  'E_45img.png',
#  'E_46img.png',
#  'E_47img.png',
#  'E_48img.png',
#  'E_49img.png',
#  'E_4img.png',
#  'E_50img.png',
#  'E_51img.png',
#  'E_52img.png',
#  'E_53img.png',
#  'E_54img.png',
#  'E_55img.png',
#  'E_56img.png',
#  'E_57img.png',
#  'E_58img.png',
#  'E_59img.png',
#  'E_5img.png',
# ...

# %%
for i in range(len(list)):
    if "E_10img" not in list[i]:
        img1 = cv2.imread(dir + list[i])
        img2 = cv2.imread(dir + list[i-1])
        img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

        error, diff = mse(img1, img2)

        cv2.imwrite("/home/jszumny/Documents/copy of smoke data/newnew/diffcloud/" + list[i], diff)

# %%
dir = "/home/jszumny/Documents/copy of smoke data/newnew/newhorizon/20160604_FIRE_rm-n-mobo-c_1465067820_+02220_lpbb_horizon_1.jpg"
for i in range(1500):
    img1 = cv2.imread(dir)
    img2 = cv2.imread(dir)
    img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
    img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

    error, diff = mse(img1, img2)

    cv2.imwrite("/home/jszumny/Documents/copy of smoke data/newnew/diffother/other" + str(i) + ".jpg", diff)
